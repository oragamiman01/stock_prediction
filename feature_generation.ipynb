# %%
from openbb import obb
import matplotlib.pyplot as plt
obb.technical
stock_data = obb.equity.price.historical(symbol="TSLA", start_date="2023-01-01", provider="yfinance")

# %%
df = stock_data.to_df().reset_index(level=['date'])
df = df.drop(columns=['dividends', 'stock_splits'])
feature = obb.technical.rsi(data=df, target='close')
df = feature.to_df().reset_index(level=['date'])
df
# Out:
#           date    open    high     low   close     volume  close_RSI_14
# 0   2023-01-03  118.47  118.80  104.64  108.10  231402800           NaN
# 1   2023-01-04  109.11  114.59  107.52  113.64  180389000           NaN
# 2   2023-01-05  110.51  111.75  107.16  110.34  157986300           NaN
# 3   2023-01-06  103.00  114.39  101.81  113.06  220911100           NaN
# 4   2023-01-09  118.96  123.52  117.11  119.77  190284000           NaN
# ..         ...     ...     ...     ...     ...        ...           ...
# 272 2024-02-02  185.04  188.69  182.00  187.91  110505100     27.596038
# 273 2024-02-05  184.26  184.68  175.01  181.06  134294400     24.481735
# 274 2024-02-06  177.21  186.49  177.11  185.10  122676000     29.532731
# 275 2024-02-07  188.18  189.79  182.68  187.58  111535200     32.516582
# 276 2024-02-08  189.00  191.62  185.58  189.56   82734654     34.887161
#
# [277 rows x 7 columns]

# %%
df.plot(x='date', y=['close_RSI_14'], figsize=(8,3))
# df.plot(x='date', y='close', figsize=(10,5))
plt.show()

# %%
feature = obb.technical.adosc(data=df)
df = feature.to_df().reset_index(level=['date'])
df
# Out:
#           date    open    high     low   close     volume  close_RSI_14  \
# 0   2023-01-03  118.47  118.80  104.64  108.10  231402800           NaN
# 1   2023-01-04  109.11  114.59  107.52  113.64  180389000           NaN
# 2   2023-01-05  110.51  111.75  107.16  110.34  157986300           NaN
# 3   2023-01-06  103.00  114.39  101.81  113.06  220911100           NaN
# 4   2023-01-09  118.96  123.52  117.11  119.77  190284000           NaN
# ..         ...     ...     ...     ...     ...        ...           ...
# 272 2024-02-02  185.04  188.69  182.00  187.91  110505100     27.596038
# 273 2024-02-05  184.26  184.68  175.01  181.06  134294400     24.481735
# 274 2024-02-06  177.21  186.49  177.11  185.10  122676000     29.532731
# 275 2024-02-07  188.18  189.79  182.68  187.58  111535200     32.516582
# 276 2024-02-08  189.00  191.62  185.58  189.56   82734654     34.887161
#
#        ADOSC_3_10
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 272 -4.009422e+07
# 273 -7.683172e+06
# 274  3.373914e+07
# 275  6.104416e+07
# 276  7.503303e+07
#
# [277 rows x 8 columns]

# %%
df.plot(x='date', y=['ADOSC_3_10'], figsize=(8,3))
# df.plot(x='date', y='close', figsize=(10,5))
plt.show()

# %%
feature = obb.technical.adx(data=df)
df = feature.to_df().reset_index(level=['date'])
df
# Out:
#           date    open    high     low   close     volume  close_RSI_14  \
# 0   2023-01-03  118.47  118.80  104.64  108.10  231402800           NaN
# 1   2023-01-04  109.11  114.59  107.52  113.64  180389000           NaN
# 2   2023-01-05  110.51  111.75  107.16  110.34  157986300           NaN
# 3   2023-01-06  103.00  114.39  101.81  113.06  220911100           NaN
# 4   2023-01-09  118.96  123.52  117.11  119.77  190284000           NaN
# ..         ...     ...     ...     ...     ...        ...           ...
# 272 2024-02-02  185.04  188.69  182.00  187.91  110505100     27.596038
# 273 2024-02-05  184.26  184.68  175.01  181.06  134294400     24.481735
# 274 2024-02-06  177.21  186.49  177.11  185.10  122676000     29.532731
# 275 2024-02-07  188.18  189.79  182.68  187.58  111535200     32.516582
# 276 2024-02-08  189.00  191.62  185.58  189.56   82734654     34.887161
#
#        ADOSC_3_10     ADX_50     DMP_50     DMN_50
# 0             NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN
# ..            ...        ...        ...        ...
# 272 -4.009422e+07   9.659995  18.850124  29.277309
# 273 -7.683172e+06   9.952409  18.323225  29.973559
# 274  3.373914e+07  10.218229  18.342998  29.364550
# 275  6.104416e+07  10.441154  18.777312  28.910214
# 276  7.503303e+07  10.638827  18.929783  28.527600
#
# [277 rows x 11 columns]

# %%
feature = obb.technical.aroon(data=df)
df = feature.to_df().reset_index(level=['date'])
df
# Out:
#           date    open    high     low   close     volume  close_RSI_14  \
# 0   2023-01-03  118.47  118.80  104.64  108.10  231402800           NaN
# 1   2023-01-04  109.11  114.59  107.52  113.64  180389000           NaN
# 2   2023-01-05  110.51  111.75  107.16  110.34  157986300           NaN
# 3   2023-01-06  103.00  114.39  101.81  113.06  220911100           NaN
# 4   2023-01-09  118.96  123.52  117.11  119.77  190284000           NaN
# ..         ...     ...     ...     ...     ...        ...           ...
# 272 2024-02-02  185.04  188.69  182.00  187.91  110505100     27.596038
# 273 2024-02-05  184.26  184.68  175.01  181.06  134294400     24.481735
# 274 2024-02-06  177.21  186.49  177.11  185.10  122676000     29.532731
# 275 2024-02-07  188.18  189.79  182.68  187.58  111535200     32.516582
# 276 2024-02-08  189.00  191.62  185.58  189.56   82734654     34.887161
#
#        ADOSC_3_10     ADX_50     DMP_50     DMN_50  AROOND_25  AROONU_25  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ..            ...        ...        ...        ...        ...        ...
# 272 -4.009422e+07   9.659995  18.850124  29.277309       76.0        4.0
# 273 -7.683172e+06   9.952409  18.323225  29.973559      100.0        0.0
# 274  3.373914e+07  10.218229  18.342998  29.364550       96.0        0.0
# 275  6.104416e+07  10.441154  18.777312  28.910214       92.0        0.0
# 276  7.503303e+07  10.638827  18.929783  28.527600       88.0        0.0
#
#      AROONOSC_25
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 272        -72.0
# 273       -100.0
# 274        -96.0
# 275        -92.0
# 276        -88.0
#
# [277 rows x 14 columns]

# %%
feature = obb.technical.cci(data=df)
df = feature.to_df().reset_index(level=['date'])
df
# Out:
#           date    open    high     low   close     volume  close_RSI_14  \
# 0   2023-01-03  118.47  118.80  104.64  108.10  231402800           NaN
# 1   2023-01-04  109.11  114.59  107.52  113.64  180389000           NaN
# 2   2023-01-05  110.51  111.75  107.16  110.34  157986300           NaN
# 3   2023-01-06  103.00  114.39  101.81  113.06  220911100           NaN
# 4   2023-01-09  118.96  123.52  117.11  119.77  190284000           NaN
# ..         ...     ...     ...     ...     ...        ...           ...
# 272 2024-02-02  185.04  188.69  182.00  187.91  110505100     27.596038
# 273 2024-02-05  184.26  184.68  175.01  181.06  134294400     24.481735
# 274 2024-02-06  177.21  186.49  177.11  185.10  122676000     29.532731
# 275 2024-02-07  188.18  189.79  182.68  187.58  111535200     32.516582
# 276 2024-02-08  189.00  191.62  185.58  189.56   82734654     34.887161
#
#        ADOSC_3_10     ADX_50     DMP_50     DMN_50  AROOND_25  AROONU_25  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ..            ...        ...        ...        ...        ...        ...
# 272 -4.009422e+07   9.659995  18.850124  29.277309       76.0        4.0
# 273 -7.683172e+06   9.952409  18.323225  29.973559      100.0        0.0
# 274  3.373914e+07  10.218229  18.342998  29.364550       96.0        0.0
# 275  6.104416e+07  10.441154  18.777312  28.910214       92.0        0.0
# 276  7.503303e+07  10.638827  18.929783  28.527600       88.0        0.0
#
#      AROONOSC_25  CCI_14_0.015
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# ..           ...           ...
# 272        -72.0    -74.591940
# 273       -100.0    -94.063932
# 274        -96.0    -72.038869
# 275        -92.0    -44.452046
# 276        -88.0    -22.492047
#
# [277 rows x 15 columns]

# %%
feature = obb.technical.cg(data=df)
df = feature.to_df().reset_index(level=['date'])
df
# Out:
#           date    open    high     low   close     volume  close_RSI_14  \
# 0   2023-01-03  118.47  118.80  104.64  108.10  231402800           NaN
# 1   2023-01-04  109.11  114.59  107.52  113.64  180389000           NaN
# 2   2023-01-05  110.51  111.75  107.16  110.34  157986300           NaN
# 3   2023-01-06  103.00  114.39  101.81  113.06  220911100           NaN
# 4   2023-01-09  118.96  123.52  117.11  119.77  190284000           NaN
# ..         ...     ...     ...     ...     ...        ...           ...
# 272 2024-02-02  185.04  188.69  182.00  187.91  110505100     27.596038
# 273 2024-02-05  184.26  184.68  175.01  181.06  134294400     24.481735
# 274 2024-02-06  177.21  186.49  177.11  185.10  122676000     29.532731
# 275 2024-02-07  188.18  189.79  182.68  187.58  111535200     32.516582
# 276 2024-02-08  189.00  191.62  185.58  189.56   82734654     34.887161
#
#        ADOSC_3_10     ADX_50     DMP_50     DMN_50  AROOND_25  AROONU_25  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ..            ...        ...        ...        ...        ...        ...
# 272 -4.009422e+07   9.659995  18.850124  29.277309       76.0        4.0
# 273 -7.683172e+06   9.952409  18.323225  29.973559      100.0        0.0
# 274  3.373914e+07  10.218229  18.342998  29.364550       96.0        0.0
# 275  6.104416e+07  10.441154  18.777312  28.910214       92.0        0.0
# 276  7.503303e+07  10.638827  18.929783  28.527600       88.0        0.0
#
#      AROONOSC_25  CCI_14_0.015     CG_14
# 0            NaN           NaN       NaN
# 1            NaN           NaN       NaN
# 2            NaN           NaN       NaN
# 3            NaN           NaN       NaN
# 4            NaN           NaN       NaN
# ..           ...           ...       ...
# 272        -72.0    -74.591940 -7.726488
# 273       -100.0    -94.063932 -7.719364
# 274        -96.0    -72.038869 -7.699504
# 275        -92.0    -44.452046 -7.671746
# 276        -88.0    -22.492047 -7.628667
#
# [277 rows x 16 columns]

# %%
feature = obb.technical.hma(data=df)
df = feature.to_df().reset_index(level=['date'])
df
# Out:
#           date    open    high     low   close     volume  close_RSI_14  \
# 0   2023-01-03  118.47  118.80  104.64  108.10  231402800           NaN
# 1   2023-01-04  109.11  114.59  107.52  113.64  180389000           NaN
# 2   2023-01-05  110.51  111.75  107.16  110.34  157986300           NaN
# 3   2023-01-06  103.00  114.39  101.81  113.06  220911100           NaN
# 4   2023-01-09  118.96  123.52  117.11  119.77  190284000           NaN
# ..         ...     ...     ...     ...     ...        ...           ...
# 272 2024-02-02  185.04  188.69  182.00  187.91  110505100     27.596038
# 273 2024-02-05  184.26  184.68  175.01  181.06  134294400     24.481735
# 274 2024-02-06  177.21  186.49  177.11  185.10  122676000     29.532731
# 275 2024-02-07  188.18  189.79  182.68  187.58  111535200     32.516582
# 276 2024-02-08  189.00  191.62  185.58  189.56   82734654     34.887161
#
#        ADOSC_3_10     ADX_50     DMP_50     DMN_50  AROOND_25  AROONU_25  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ..            ...        ...        ...        ...        ...        ...
# 272 -4.009422e+07   9.659995  18.850124  29.277309       76.0        4.0
# 273 -7.683172e+06   9.952409  18.323225  29.973559      100.0        0.0
# 274  3.373914e+07  10.218229  18.342998  29.364550       96.0        0.0
# 275  6.104416e+07  10.441154  18.777312  28.910214       92.0        0.0
# 276  7.503303e+07  10.638827  18.929783  28.527600       88.0        0.0
#
#      AROONOSC_25  CCI_14_0.015     CG_14  close_HMA_50
# 0            NaN           NaN       NaN           NaN
# 1            NaN           NaN       NaN           NaN
# 2            NaN           NaN       NaN           NaN
# 3            NaN           NaN       NaN           NaN
# 4            NaN           NaN       NaN           NaN
# ..           ...           ...       ...           ...
# 272        -72.0    -74.591940 -7.726488    194.889691
# 273       -100.0    -94.063932 -7.719364    191.236630
# 274        -96.0    -72.038869 -7.699504    187.904153
# 275        -92.0    -44.452046 -7.671746    184.949417
# 276        -88.0    -22.492047 -7.628667    182.435444
#
# [277 rows x 17 columns]

# %%
feature = obb.technical.ichimoku(data=df)
df = feature.to_df().reset_index(level=['date'])
df
# Out:
#           date    open    high     low   close     volume  close_RSI_14  \
# 0   2023-01-03  118.47  118.80  104.64  108.10  231402800           NaN
# 1   2023-01-04  109.11  114.59  107.52  113.64  180389000           NaN
# 2   2023-01-05  110.51  111.75  107.16  110.34  157986300           NaN
# 3   2023-01-06  103.00  114.39  101.81  113.06  220911100           NaN
# 4   2023-01-09  118.96  123.52  117.11  119.77  190284000           NaN
# ..         ...     ...     ...     ...     ...        ...           ...
# 272 2024-02-02  185.04  188.69  182.00  187.91  110505100     27.596038
# 273 2024-02-05  184.26  184.68  175.01  181.06  134294400     24.481735
# 274 2024-02-06  177.21  186.49  177.11  185.10  122676000     29.532731
# 275 2024-02-07  188.18  189.79  182.68  187.58  111535200     32.516582
# 276 2024-02-08  189.00  191.62  185.58  189.56   82734654     34.887161
#
#        ADOSC_3_10     ADX_50     DMP_50  ...  AROOND_25  AROONU_25  \
# 0             NaN        NaN        NaN  ...        NaN        NaN
# 1             NaN        NaN        NaN  ...        NaN        NaN
# 2             NaN        NaN        NaN  ...        NaN        NaN
# 3             NaN        NaN        NaN  ...        NaN        NaN
# 4             NaN        NaN        NaN  ...        NaN        NaN
# ..            ...        ...        ...  ...        ...        ...
# 272 -4.009422e+07   9.659995  18.850124  ...       76.0        4.0
# 273 -7.683172e+06   9.952409  18.323225  ...      100.0        0.0
# 274  3.373914e+07  10.218229  18.342998  ...       96.0        0.0
# 275  6.104416e+07  10.441154  18.777312  ...       92.0        0.0
# 276  7.503303e+07  10.638827  18.929783  ...       88.0        0.0
#
#      AROONOSC_25  CCI_14_0.015     CG_14  close_HMA_50     ISA_9   ISB_26  \
# 0            NaN           NaN       NaN           NaN       NaN      NaN
# 1            NaN           NaN       NaN           NaN       NaN      NaN
# 2            NaN           NaN       NaN           NaN       NaN      NaN
# 3            NaN           NaN       NaN           NaN       NaN      NaN
# 4            NaN           NaN       NaN           NaN       NaN      NaN
# ..           ...           ...       ...           ...       ...      ...
# 272        -72.0    -74.591940 -7.726488    194.889691  227.9675  236.525
# 273       -100.0    -94.063932 -7.719364    191.236630  226.5150  236.525
# 274        -96.0    -72.038869 -7.699504    187.904153  225.9100  236.525
# 275        -92.0    -44.452046 -7.671746    184.949417  225.9100  236.525
# 276        -88.0    -22.492047 -7.628667    182.435444  225.2725  236.525
#
#        ITS_9   IKS_26
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 272  244.020  243.190
# 273  252.065  245.770
# 274  256.065  246.665
# 275  256.065  246.665
# 276  254.770  246.665
#
# [277 rows x 21 columns]

# %%
feature = obb.technical.vwap(data=df)
df = feature.to_df().reset_index(level=['date'])
df
# Out:
#           date    open    high     low   close     volume  close_RSI_14  \
# 0   2023-01-03  118.47  118.80  104.64  108.10  231402800           NaN
# 1   2023-01-04  109.11  114.59  107.52  113.64  180389000           NaN
# 2   2023-01-05  110.51  111.75  107.16  110.34  157986300           NaN
# 3   2023-01-06  103.00  114.39  101.81  113.06  220911100           NaN
# 4   2023-01-09  118.96  123.52  117.11  119.77  190284000           NaN
# ..         ...     ...     ...     ...     ...        ...           ...
# 272 2024-02-02  185.04  188.69  182.00  187.91  110505100     27.596038
# 273 2024-02-05  184.26  184.68  175.01  181.06  134294400     24.481735
# 274 2024-02-06  177.21  186.49  177.11  185.10  122676000     29.532731
# 275 2024-02-07  188.18  189.79  182.68  187.58  111535200     32.516582
# 276 2024-02-08  189.00  191.62  185.58  189.56   82734654     34.887161
#
#        ADOSC_3_10     ADX_50     DMP_50  ...  AROONU_25  AROONOSC_25  \
# 0             NaN        NaN        NaN  ...        NaN          NaN
# 1             NaN        NaN        NaN  ...        NaN          NaN
# 2             NaN        NaN        NaN  ...        NaN          NaN
# 3             NaN        NaN        NaN  ...        NaN          NaN
# 4             NaN        NaN        NaN  ...        NaN          NaN
# ..            ...        ...        ...  ...        ...          ...
# 272 -4.009422e+07   9.659995  18.850124  ...        4.0        -72.0
# 273 -7.683172e+06   9.952409  18.323225  ...        0.0       -100.0
# 274  3.373914e+07  10.218229  18.342998  ...        0.0        -96.0
# 275  6.104416e+07  10.441154  18.777312  ...        0.0        -92.0
# 276  7.503303e+07  10.638827  18.929783  ...        0.0        -88.0
#
#      CCI_14_0.015     CG_14  close_HMA_50     ISA_9   ISB_26    ITS_9  \
# 0             NaN       NaN           NaN       NaN      NaN      NaN
# 1             NaN       NaN           NaN       NaN      NaN      NaN
# 2             NaN       NaN           NaN       NaN      NaN      NaN
# 3             NaN       NaN           NaN       NaN      NaN      NaN
# 4             NaN       NaN           NaN       NaN      NaN      NaN
# ..            ...       ...           ...       ...      ...      ...
# 272    -74.591940 -7.726488    194.889691  227.9675  236.525  244.020
# 273    -94.063932 -7.719364    191.236630  226.5150  236.525  252.065
# 274    -72.038869 -7.699504    187.904153  225.9100  236.525  256.065
# 275    -44.452046 -7.671746    184.949417  225.9100  236.525  256.065
# 276    -22.492047 -7.628667    182.435444  225.2725  236.525  254.770
#
#       IKS_26      VWAP_D
# 0        NaN  110.513333
# 1        NaN  111.916667
# 2        NaN  109.750000
# 3        NaN  109.753333
# 4        NaN  120.133333
# ..       ...         ...
# 272  243.190  186.200000
# 273  245.770  180.250000
# 274  246.665  182.900000
# 275  246.665  186.683333
# 276  246.665  188.920000
#
# [277 rows x 22 columns]

# %%
df = df.dropna() # to drop rows with NaN
df
# Out:
#           date    open    high     low   close     volume  close_RSI_14  \
# 103 2023-06-01  202.59  209.80  199.37  207.52  148029900     73.506947
# 104 2023-06-02  210.15  217.25  209.75  213.97  164129000     76.348543
# 105 2023-06-05  217.80  221.29  214.52  217.61  151143100     77.795945
# 106 2023-06-06  216.14  221.91  212.53  221.31  146911600     79.190025
# 107 2023-06-07  228.00  230.83  223.20  224.57  185710800     80.360053
# ..         ...     ...     ...     ...     ...        ...           ...
# 272 2024-02-02  185.04  188.69  182.00  187.91  110505100     27.596038
# 273 2024-02-05  184.26  184.68  175.01  181.06  134294400     24.481735
# 274 2024-02-06  177.21  186.49  177.11  185.10  122676000     29.532731
# 275 2024-02-07  188.18  189.79  182.68  187.58  111535200     32.516582
# 276 2024-02-08  189.00  191.62  185.58  189.56   82734654     34.887161
#
#        ADOSC_3_10     ADX_50     DMP_50  ...  AROONU_25  AROONOSC_25  \
# 103  1.515881e+08  10.668609  31.133980  ...      100.0         96.0
# 104  1.572352e+08  11.103940  32.319963  ...      100.0        100.0
# 105  1.410602e+08  11.568486  32.769277  ...      100.0        100.0
# 106  1.623840e+08  11.976346  31.948592  ...      100.0        100.0
# 107  1.184750e+08  12.466995  33.509676  ...      100.0        100.0
# ..            ...        ...        ...  ...        ...          ...
# 272 -4.009422e+07   9.659995  18.850124  ...        4.0        -72.0
# 273 -7.683172e+06   9.952409  18.323225  ...        0.0       -100.0
# 274  3.373914e+07  10.218229  18.342998  ...        0.0        -96.0
# 275  6.104416e+07  10.441154  18.777312  ...        0.0        -92.0
# 276  7.503303e+07  10.638827  18.929783  ...        0.0        -88.0
#
#      CCI_14_0.015     CG_14  close_HMA_50     ISA_9   ISB_26    ITS_9  \
# 103    141.498637 -7.225258    180.277649  184.9175  159.730  174.150
# 104    154.918605 -7.202981    184.087741  182.9925  159.730  171.415
# 105    143.732387 -7.195007    188.204000  185.8675  159.730  171.030
# 106    122.555046 -7.197231    192.563929  186.5325  159.730  170.030
# 107    134.028154 -7.191217    197.085758  186.5325  166.285  167.935
# ..            ...       ...           ...       ...      ...      ...
# 272    -74.591940 -7.726488    194.889691  227.9675  236.525  244.020
# 273    -94.063932 -7.719364    191.236630  226.5150  236.525  252.065
# 274    -72.038869 -7.699504    187.904153  225.9100  236.525  256.065
# 275    -44.452046 -7.671746    184.949417  225.9100  236.525  256.065
# 276    -22.492047 -7.628667    182.435444  225.2725  236.525  254.770
#
#       IKS_26      VWAP_D
# 103  183.200  205.563333
# 104  180.465  213.656667
# 105  180.080  217.806667
# 106  180.080  218.583333
# 107  180.080  226.200000
# ..       ...         ...
# 272  243.190  186.200000
# 273  245.770  180.250000
# 274  246.665  182.900000
# 275  246.665  186.683333
# 276  246.665  188.920000
#
# [174 rows x 22 columns]
